# %%
from sklearn.datasets import make_blobs
from sklearn.datasets import make_classification
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split

# %%
blobs = make_blobs(n_samples=50, n_features=2, centers=4, cluster_std=1.8, random_state=142)
X = blobs[0]
y = blobs[1]
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
#data = make_classification(n_samples=1000, n_features=2, n_informative=2,n_redundant=0,n_repeated=0,n_classes=4,class_sep=1.2,n_clusters_per_class=1,scale =3)
#X = data[0]
#y = data[1]
#plt.scatter(X[:,0], X[:,1], c=y)
#plt.show()

# %%
def plot(X, y,Xt,yt, model):
    try:
        X = np.array(X)
        y = np.array(y).flatten()
    except:
        print("Failed to load")
    reduced_data = X[:, :2]

    h = .02        
    x_min, x_max = reduced_data[:, 0].min() - 1, reduced_data[:, 0].max() + 1
    y_min, y_max = reduced_data[:, 1].min() - 1, reduced_data[:, 1].max() + 1

    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])    

    x_min, x_max = X[:, 0].min() - 4, X[:, 0].max() + 4
    y_min, y_max = X[:, 1].min() - 4, X[:, 1].max() + 4
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                         np.arange(y_min, y_max, 0.1))

    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
    
    plt.figure(1) 
    plt.title("Zbiór uczący",fontsize=15)
    plt.contourf(xx, yy, Z, alpha=0.4)
    plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.8)
    plt.xlabel("Dokładność: " + str(model.score(X,y)),fontsize=15)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    
    plt.figure(2) 
    plt.title("Zbiór testowy",fontsize=15)
    plt.contourf(xx, yy, Z, alpha=0.4)
    plt.scatter(Xt[:, 0], Xt[:, 1], c=yt, alpha=0.8)
    plt.xlabel("Dokładność: " + str(model.score(Xt,yt)),fontsize=15)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
   
    return plt

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
layers = (10,10,10,10,10,10,10,10,10,10,10,10,10,10)

# %%
model = MLPClassifier(hidden_layer_sizes = layers, activation = 'tanh', solver = 'adam', max_iter = 1000,tol=0.0001,n_iter_no_change = 50, verbose = True)

# %%
model.fit(X_train, Y_train)
# Out:
# Iteration 1, loss = 1.45642369
# Iteration 2, loss = 1.44328984
# Iteration 3, loss = 1.43115222
# Iteration 4, loss = 1.41984671
# Iteration 5, loss = 1.40922211
# Iteration 6, loss = 1.39916360
# Iteration 7, loss = 1.38959234
# Iteration 8, loss = 1.38045959
# Iteration 9, loss = 1.37173689
# Iteration 10, loss = 1.36340177
# Iteration 11, loss = 1.35542010
# Iteration 12, loss = 1.34773573
# Iteration 13, loss = 1.34027181
# Iteration 14, loss = 1.33293980
# Iteration 15, loss = 1.32564981
# Iteration 16, loss = 1.31831950
# Iteration 17, loss = 1.31087871
# Iteration 18, loss = 1.30326964
# Iteration 19, loss = 1.29544423
# Iteration 20, loss = 1.28736061
# Iteration 21, loss = 1.27897977
# Iteration 22, loss = 1.27026307
# Iteration 23, loss = 1.26117114
# Iteration 24, loss = 1.25166413
# Iteration 25, loss = 1.24170320
# Iteration 26, loss = 1.23125339
# Iteration 27, loss = 1.22028759
# Iteration 28, loss = 1.20879124
# Iteration 29, loss = 1.19676631
# Iteration 30, loss = 1.18423342
# Iteration 31, loss = 1.17123095
# Iteration 32, loss = 1.15781127
# Iteration 33, loss = 1.14403519
# Iteration 34, loss = 1.12996665
# Iteration 35, loss = 1.11566899
# Iteration 36, loss = 1.10120222
# Iteration 37, loss = 1.08661843
# Iteration 38, loss = 1.07195328
